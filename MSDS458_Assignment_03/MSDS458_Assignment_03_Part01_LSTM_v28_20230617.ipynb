# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/main/images2/NorthwesternHeader.png?raw=1" />

# %% [markdown]
# ## MSDS458 Research Assignment 3 - Part 01 LSTM

# %% [markdown]
# ### Analyze AG_NEWS_SUBSET Data <br>
#
# AG is a collection of more than 1 million news articles. News articles have been gathered from more than 2000 news sources by ComeToMyHead in more than 1 year of activity. ComeToMyHead is an academic news search engine which has been running since July, 2004. The dataset is provided by the academic comunity for research purposes in data mining (clustering, classification, etc), information retrieval (ranking, search, etc), xml, data compression, data streaming, and any other non-commercial activity.<br>
#
# For more information, please refer to the link http://www.di.unipi.it/~gulli/AG_corpus_of_news_articles.html<br>
#
#
# The AG's news topic classification dataset is constructed by choosing 4 largest classes (**World**, **Sports**, **Business**, and **Sci/Tech**) from the original corpus. Each class contains 30,000 training samples and 1,900 testing samples. The total number of training samples is 120,000 and testing 7,600.<br>
#
# Homepage: https://arxiv.org/abs/1509.01626<br>
#
# Source code: tfds.text.AGNewsSubset
#
# Versions:
#
# 1.0.0 (default): No release notes.
# Download size: 11.24 MiB
#
# Dataset size: 35.79 MiB

# %% [markdown]
# ### References
# 1. Deep Learning with Python, Francois Chollet (https://learning.oreilly.com/library/view/deep-learning-with/9781617296864/)
#  * Chapter 10: Deep learning for time series
#  * Chapter 11: Deep learning for text
# 2. Deep Learning A Visual Approach, Andrew Glassner (https://learning.oreilly.com/library/view/deep-learning/9781098129019/)
#  * Chapter 19: Recurrent Neural Networks
#  * Chapter 20: Attention and Transformers

# %% [markdown]
# ### Processing words as a sequence: The sequence model approach
#
# To implement a sequence model, you’d start by representing your input samples as sequences of integer indices (one integer standing for one word). Then, you’d map each integer to a vector to obtain vector sequences. Finally, you’d feed these sequences of vectors into a stack of layers that could cross-correlate features from adjacent vectors, such as a 1D convnet, a RNN, or a Transformer.

# %% [markdown]
# For some time around 2016–2017, bidirectional RNNs (in particular, `bidirectional LSTMs`) were considered to be the state of the art for sequence modeling. However, nowadays sequence modeling is almost universally done with `Transformers`.
#
# F. Chollet: "One-dimensional convnets were never very popular in NLP, even though, a residual stack of depthwise-separable 1D convolutions can often achieve comparable performance to a bidirectional LSTM, at a greatly reduced computational cost."

# %% [markdown]
# ### Import Packages

# %%
from packaging import version
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import string

import seaborn as sns
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as k

import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ### Verify TensorFlow version and Keras version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.12.0

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.12.0

# %% [markdown]
# ### Stopword Function

# %%
def custom_stopwords(input_text):
    lowercase = tf.strings.lower(input_text)
    stripped_punct = tf.strings.regex_replace(lowercase
                                  ,'[%s]' % re.escape(string.punctuation)
                                  ,'')
    return tf.strings.regex_replace(stripped_punct, r'\b(' + r'|'.join(STOPWORDS) + r')\b\s*',"")

# %% [markdown]
# ### Plotting Model Performance Metrics

# %%
def display_training_curves(training, validation, title, subplot):
  ax = plt.subplot(subplot)
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['training', 'validation'])

def print_validation_report(test_labels, predictions):
    print("Classification Report")
    print(classification_report(test_labels, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(test_labels, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(test_labels, predictions))))

def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(16,12))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ### Mount Google Drive to Colab environment

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %% [markdown]
# ### Load Data

# %%
# register  ag_news_subset so that tfds.load doesn't generate a checksum (mismatch) error
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums --datasets=ag_news_subset

dataset,info=\
tfds.load('ag_news_subset', with_info=True,  split=['train[:95%]','train[95%:]', 'test'],batch_size = 32
          , as_supervised=True)

train_ds, val_ds, test_ds = dataset
text_only_train_ds = train_ds.map(lambda x, y: x)
# Out:
# W0618 00:22:45.426684 140011305625408 download_and_prepare.py:46] ***`tfds build` should be used instead of `download_and_prepare`.***
# INFO[build.py]: Loading dataset ag_news_subset from imports: tensorflow_datasets.datasets.ag_news_subset.ag_news_subset_dataset_builder
# 2023-06-18 00:22:46.572780: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-18 00:22:48.585540: W tensorflow/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# INFO[dataset_info.py]: Load pre-computed DatasetInfo (eg: splits, num examples,...) from GCS: ag_news_subset/1.0.0
# INFO[dataset_info.py]: Load dataset info from /tmp/tmpqvmkotrltfds
# INFO[dataset_info.py]: Fields info.[description, splits, supervised_keys, module_name] from disk and from code do not match. Keeping the one from code.
# INFO[build.py]: download_and_prepare for dataset ag_news_subset/1.0.0...
# INFO[dataset_builder.py]: Generating dataset ag_news_subset (/root/tensorflow_datasets/ag_news_subset/1.0.0)
# Downloading and preparing dataset 11.24 MiB (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to /root/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
#
#
#
# INFO[download_manager.py]: Downloading https://drive.google.com/uc?export=download&id=0Bz8a_Dbh9QhbUDNpeUdjb0wxRms into /root/tensorflow_datasets/downloads/ucexport_download_id_0Bz8a_Dbh9QhbUDNpeUdjb0wxj4g1umFAV8OV-uDwxSJR0LdxO_k1jxMuFWwAfNX9jos.tmp.35dc6c9b380b433c853ac7863c04e23c...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:   0% 0/11 [00:14<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:14, ? file/s]
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:   9% 1/11 [00:14<02:27, 14.75s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:  18% 2/11 [00:14<02:12, 14.75s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:  27% 3/11 [00:14<01:57, 14.75s/ MiB]
#
# Extraction completed...: 0 file [00:14, ? file/s]
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:  36% 4/11 [00:14<00:19,  2.82s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:  45% 5/11 [00:14<00:16,  2.82s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:  55% 6/11 [00:14<00:14,  2.82s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:  64% 7/11 [00:14<00:11,  2.82s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:  73% 8/11 [00:14<00:08,  2.82s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:  82% 9/11 [00:14<00:05,  2.82s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...:  91% 10/11 [00:14<00:02,  2.82s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:14<?, ? url/s]
# Dl Size...: 100% 11/11 [00:14<00:00,  2.82s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:14<00:00, 14.91s/ url]
# Dl Size...: 100% 11/11 [00:14<00:00,  2.82s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 14.91s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.82s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 14.91s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.82s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 14.91s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.82s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 14.91s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.82s/ MiB]
#
# Extraction completed...:   0% 0/4 [00:15<?, ? file/s]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 14.91s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.82s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 14.91s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.82s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 14.91s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.82s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 14.91s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.82s/ MiB]
#
# Extraction completed...: 100% 4/4 [00:15<00:00,  3.79s/ file]
# Dl Size...: 100% 11/11 [00:15<00:00,  1.38s/ MiB]
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.15s/ url]
# Generating splits...:   0% 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0% 0/120000 [00:00<?, ? examples/s]
# Generating train examples...:   1% 1227/120000 [00:00<00:09, 12266.47 examples/s]
# Generating train examples...:   2% 2454/120000 [00:00<00:09, 12262.52 examples/s]
# Generating train examples...:   3% 3715/120000 [00:00<00:09, 12419.52 examples/s]
# Generating train examples...:   4% 4957/120000 [00:00<00:09, 12292.36 examples/s]
# Generating train examples...:   5% 6191/120000 [00:00<00:09, 12306.65 examples/s]
# Generating train examples...:   6% 7422/120000 [00:00<00:09, 12303.13 examples/s]
# Generating train examples...:   7% 8698/120000 [00:00<00:08, 12448.88 examples/s]
# Generating train examples...:   8% 9945/120000 [00:00<00:08, 12455.36 examples/s]
# Generating train examples...:   9% 11216/120000 [00:00<00:08, 12533.39 examples/s]
# Generating train examples...:  10% 12494/120000 [00:01<00:08, 12608.22 examples/s]
# Generating train examples...:  11% 13768/120000 [00:01<00:08, 12647.67 examples/s]
# Generating train examples...:  13% 15033/120000 [00:01<00:08, 12632.18 examples/s]
# Generating train examples...:  14% 16301/120000 [00:01<00:08, 12645.34 examples/s]
# Generating train examples...:  15% 17566/120000 [00:01<00:08, 12468.58 examples/s]
# Generating train examples...:  16% 18819/120000 [00:01<00:08, 12485.58 examples/s]
# Generating train examples...:  17% 20071/120000 [00:01<00:07, 12493.68 examples/s]
# Generating train examples...:  18% 21380/120000 [00:01<00:07, 12671.49 examples/s]
# Generating train examples...:  19% 22659/120000 [00:01<00:07, 12705.37 examples/s]
# Generating train examples...:  20% 23954/120000 [00:01<00:07, 12777.23 examples/s]
# Generating train examples...:  21% 25232/120000 [00:02<00:07, 12616.98 examples/s]
# Generating train examples...:  22% 26495/120000 [00:02<00:07, 12611.02 examples/s]
# Generating train examples...:  23% 27789/120000 [00:02<00:07, 12706.35 examples/s]
# Generating train examples...:  24% 29065/120000 [00:02<00:07, 12719.49 examples/s]
# Generating train examples...:  25% 30338/120000 [00:02<00:07, 12609.56 examples/s]
# Generating train examples...:  26% 31600/120000 [00:02<00:07, 12598.42 examples/s]
# Generating train examples...:  27% 32861/120000 [00:02<00:07, 12436.16 examples/s]
# Generating train examples...:  28% 34130/120000 [00:02<00:06, 12508.83 examples/s]
# Generating train examples...:  29% 35382/120000 [00:02<00:06, 12329.66 examples/s]
# Generating train examples...:  31% 36652/120000 [00:02<00:06, 12436.71 examples/s]
# Generating train examples...:  32% 37897/120000 [00:03<00:06, 12373.11 examples/s]
# Generating train examples...:  33% 39135/120000 [00:03<00:06, 12369.09 examples/s]
# Generating train examples...:  34% 40373/120000 [00:03<00:06, 12116.60 examples/s]
# Generating train examples...:  35% 41586/120000 [00:03<00:06, 11890.09 examples/s]
# Generating train examples...:  36% 42777/120000 [00:03<00:06, 11787.34 examples/s]
# Generating train examples...:  37% 44032/120000 [00:03<00:06, 12007.61 examples/s]
# Generating train examples...:  38% 45234/120000 [00:03<00:06, 11950.99 examples/s]
# Generating train examples...:  39% 46468/120000 [00:03<00:06, 12064.74 examples/s]
# Generating train examples...:  40% 47676/120000 [00:03<00:06, 11834.10 examples/s]
# Generating train examples...:  41% 48925/120000 [00:03<00:05, 12025.61 examples/s]
# Generating train examples...:  42% 50200/120000 [00:04<00:05, 12238.66 examples/s]
# Generating train examples...:  43% 51426/120000 [00:04<00:05, 12167.25 examples/s]
# Generating train examples...:  44% 52715/120000 [00:04<00:05, 12380.19 examples/s]
# Generating train examples...:  45% 53954/120000 [00:04<00:05, 12270.48 examples/s]
# Generating train examples...:  46% 55198/120000 [00:04<00:05, 12317.80 examples/s]
# Generating train examples...:  47% 56431/120000 [00:04<00:05, 12186.77 examples/s]
# Generating train examples...:  48% 57651/120000 [00:04<00:05, 12073.87 examples/s]
# Generating train examples...:  49% 58859/120000 [00:04<00:05, 12057.32 examples/s]
# Generating train examples...:  50% 60069/120000 [00:04<00:04, 12069.47 examples/s]
# Generating train examples...:  51% 61299/120000 [00:04<00:04, 12137.64 examples/s]
# Generating train examples...:  52% 62514/120000 [00:05<00:04, 12050.36 examples/s]
# Generating train examples...:  53% 63720/120000 [00:05<00:04, 12000.55 examples/s]
# Generating train examples...:  54% 64921/120000 [00:05<00:04, 11930.25 examples/s]
# Generating train examples...:  55% 66153/120000 [00:05<00:04, 12042.44 examples/s]
# Generating train examples...:  56% 67358/120000 [00:05<00:04, 12010.39 examples/s]
# Generating train examples...:  57% 68560/120000 [00:05<00:04, 11981.10 examples/s]
# Generating train examples...:  58% 69785/120000 [00:05<00:04, 12058.53 examples/s]
# Generating train examples...:  59% 70991/120000 [00:05<00:04, 12000.53 examples/s]
# Generating train examples...:  60% 72248/120000 [00:05<00:03, 12168.86 examples/s]
# Generating train examples...:  61% 73472/120000 [00:05<00:03, 12189.93 examples/s]
# Generating train examples...:  62% 74719/120000 [00:06<00:03, 12272.75 examples/s]
# Generating train examples...:  63% 75972/120000 [00:06<00:03, 12348.49 examples/s]
# Generating train examples...:  64% 77223/120000 [00:06<00:03, 12394.64 examples/s]
# Generating train examples...:  65% 78463/120000 [00:06<00:03, 12332.38 examples/s]
# Generating train examples...:  66% 79697/120000 [00:06<00:03, 12026.25 examples/s]
# Generating train examples...:  67% 80902/120000 [00:06<00:03, 12029.81 examples/s]
# Generating train examples...:  68% 82146/120000 [00:06<00:03, 12149.46 examples/s]
# Generating train examples...:  69% 83397/120000 [00:06<00:02, 12255.04 examples/s]
# Generating train examples...:  71% 84668/120000 [00:06<00:02, 12390.14 examples/s]
# Generating train examples...:  72% 85908/120000 [00:06<00:02, 12379.61 examples/s]
# Generating train examples...:  73% 87147/120000 [00:07<00:02, 12256.67 examples/s]
# Generating train examples...:  74% 88407/120000 [00:07<00:02, 12357.52 examples/s]
# Generating train examples...:  75% 89644/120000 [00:07<00:02, 12273.96 examples/s]
# Generating train examples...:  76% 90893/120000 [00:07<00:02, 12337.75 examples/s]
# Generating train examples...:  77% 92128/120000 [00:07<00:02, 12199.42 examples/s]
# Generating train examples...:  78% 93355/120000 [00:07<00:02, 12217.66 examples/s]
# Generating train examples...:  79% 94617/120000 [00:07<00:02, 12335.10 examples/s]
# Generating train examples...:  80% 95851/120000 [00:07<00:01, 12311.30 examples/s]
# Generating train examples...:  81% 97110/120000 [00:07<00:01, 12392.13 examples/s]
# Generating train examples...:  82% 98353/120000 [00:07<00:01, 12401.58 examples/s]
# Generating train examples...:  83% 99594/120000 [00:08<00:01, 11834.75 examples/s]
# Generating train examples...:  84% 100783/120000 [00:08<00:01, 11717.49 examples/s]
# Generating train examples...:  85% 101959/120000 [00:08<00:01, 11607.56 examples/s]
# Generating train examples...:  86% 103199/120000 [00:08<00:01, 11835.76 examples/s]
# Generating train examples...:  87% 104413/120000 [00:08<00:01, 11924.46 examples/s]
# Generating train examples...:  88% 105608/120000 [00:08<00:01, 11742.58 examples/s]
# Generating train examples...:  89% 106815/120000 [00:08<00:01, 11837.82 examples/s]
# Generating train examples...:  90% 108001/120000 [00:08<00:01, 11774.80 examples/s]
# Generating train examples...:  91% 109224/120000 [00:08<00:00, 11908.74 examples/s]
# Generating train examples...:  92% 110504/120000 [00:09<00:00, 12171.45 examples/s]
# Generating train examples...:  93% 111754/120000 [00:09<00:00, 12268.82 examples/s]
# Generating train examples...:  94% 112982/120000 [00:09<00:00, 12095.37 examples/s]
# Generating train examples...:  95% 114193/120000 [00:09<00:00, 12049.22 examples/s]
# Generating train examples...:  96% 115399/120000 [00:09<00:00, 11780.88 examples/s]
# Generating train examples...:  97% 116579/120000 [00:09<00:00, 11724.37 examples/s]
# Generating train examples...:  98% 117833/120000 [00:09<00:00, 11962.63 examples/s]
# Generating train examples...:  99% 119085/120000 [00:09<00:00, 12125.24 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteUU99QR/ag_news_subset-train.tfrecord*...:   0% 0/120000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteUU99QR/ag_news_subset-train.tfrecord*...:  12% 14658/120000 [00:00<00:00, 146572.10 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteUU99QR/ag_news_subset-train.tfrecord*...:  55% 65558/120000 [00:00<00:00, 359746.83 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteUU99QR/ag_news_subset-train.tfrecord*...:  97% 116948/120000 [00:00<00:00, 430125.42 examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteUU99QR/ag_news_subset-train.tfrecord*. Number of examples: 120000 (shards: [120000])
# Generating splits...:  50% 1/2 [00:10<00:10, 10.15s/ splits]
# Generating test examples...:   0% 0/7600 [00:00<?, ? examples/s]
# Generating test examples...:  16% 1188/7600 [00:00<00:00, 11874.04 examples/s]
# Generating test examples...:  32% 2448/7600 [00:00<00:00, 12299.15 examples/s]
# Generating test examples...:  48% 3678/7600 [00:00<00:00, 12135.41 examples/s]
# Generating test examples...:  64% 4892/7600 [00:00<00:00, 12061.93 examples/s]
# Generating test examples...:  81% 6147/7600 [00:00<00:00, 12234.06 examples/s]
# Generating test examples...:  97% 7379/7600 [00:00<00:00, 12262.11 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteUU99QR/ag_news_subset-test.tfrecord*...:   0% 0/7600 [00:00<?, ? examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteUU99QR/ag_news_subset-test.tfrecord*. Number of examples: 7600 (shards: [7600])
# Dataset ag_news_subset downloaded and prepared to /root/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.
# INFO[build.py]: Dataset generation complete...
#
# tfds.core.DatasetInfo(
#     name='ag_news_subset',
#     full_name='ag_news_subset/1.0.0',
#     description="""
#     AG is a collection of more than 1 million news articles. News articles have been
#     gathered from more than 2000 news sources by ComeToMyHead in more than 1 year of
#     activity. ComeToMyHead is an academic news search engine which has been running
#     since July, 2004. The dataset is provided by the academic comunity for research
#     purposes in data mining (clustering, classification, etc), information retrieval
#     (ranking, search, etc), xml, data compression, data streaming, and any other
#     non-commercial activity. For more information, please refer to the link
#     http://www.di.unipi.it/~gulli/AG_corpus_of_news_articles.html .
#
#     The AG's news topic classification dataset is constructed by Xiang Zhang
#     (xiang.zhang@nyu.edu) from the dataset above. It is used as a text
#     classification benchmark in the following paper: Xiang Zhang, Junbo Zhao, Yann
#     LeCun. Character-level Convolutional Networks for Text Classification. Advances
#     in Neural Information Processing Systems 28 (NIPS 2015).
#
#     The AG's news topic classification dataset is constructed by choosing 4 largest
#     classes from the original corpus. Each class contains 30,000 training samples
#     and 1,900 testing samples. The total number of training samples is 120,000 and
#     testing 7,600.
#     """,
#     homepage='https://arxiv.org/abs/1509.01626',
#     data_path=PosixGPath('/tmp/tmpqvmkotrltfds'),
#     file_format=tfrecord,
#     download_size=11.24 MiB,
#     dataset_size=35.79 MiB,
#     features=FeaturesDict({
#         'description': Text(shape=(), dtype=string),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=4),
#         'title': Text(shape=(), dtype=string),
#     }),
#     supervised_keys=('description', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=7600, num_shards=1>,
#         'train': <SplitInfo num_examples=120000, num_shards=1>,
#     },
#     citation="""@misc{zhang2015characterlevel,
#         title={Character-level Convolutional Networks for Text Classification},
#         author={Xiang Zhang and Junbo Zhao and Yann LeCun},
#         year={2015},
#         eprint={1509.01626},
#         archivePrefix={arXiv},
#         primaryClass={cs.LG}
#     }""",
# )

# %% [markdown]
# ### Preparing Integer Sequence Datasets

# %%
nltk.download('stopwords',quiet=True)
STOPWORDS = stopwords.words("english")

# %%
max_length = 96
max_tokens = 1000
text_vectorization = layers.TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    output_sequence_length=max_length,
    standardize=custom_stopwords
)
text_vectorization.adapt(text_only_train_ds)

int_train_ds = train_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_val_ds = val_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_test_ds = test_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)

# %% [markdown]
# ### Bi-directional RNN
#
# When translating in real-time, it would help to have access to worlds towards the end of a sentence, say, as well as earlier words in the sentence. One way to use the later words in the sentence is to feed the words into our RNN backward. So if we create two independent RNNs, we can feed one the words in their forward, or natural order, and the second gets their words in the revser order. This is the idea behind `Bi-directional RNNS`:

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/main/images2/BidirectionalRNN.png?raw=1">

# %% [markdown]
# ### Understanding word embeddings

# %% [markdown]
# When you encode something via `one-hot encoding`, you’re making a feature-engineering decision. You’re injecting into your model a fundamental assumption about the structure of your feature space. That assumption is that the different tokens you’re encoding are all independent from each other: indeed, one-hot vectors are all orthogonal to one another.

# %% [markdown]
# However, in a reasonable word vector space, you would expect synonyms to be embedded into similar word vectors, and in general, you would expect the geometric distance  between any two word vectors to relate to the “semantic distance” between the associated words.
#
# Words that mean different things should lie far away from each other, whereas related words should be closer.

# %% [markdown]
# `Word embeddings` are vector representations of words that achieve exactly this: they map human language into a structured geometric space.

# %% [markdown]
# Whereas the vectors obtained through `one-hot encoding` are *binary*, *sparse*, and *very high-dimensional* (the same dimensionality as the number of words in the vocabulary), `word embeddings` are *low-dimensional floating-point vectors* (that is, `dense vectors`, as opposed to `sparse vectors`).

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/main/images2/EmbeddingsSparse.png?raw=1">

# %% [markdown]
# ### Two ways to obtain word embeddings
#
# 1. `Learn word embeddings jointly with the main task you care about` (such as document classification or sentiment prediction). In this setup, you start with random word vectors and then learn word vectors in the same way you learn the weights of a neural network.
# 2. Load into your model word embeddings that were precomputed using a different machine learning task than the one you’re trying to solve. These are called `pretrained word embeddings`.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>tf.keras.layers.Embedding</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding </div>

# %% [markdown]
# ### Understanding Padding and Masking

# %% [markdown]
# One thing that’s slightly hurting model performance here is that our input sequences are full of zeros. This comes from our use of the `output_sequence_length=max_ length` option in TextVectorization (with `max_length equal` to 150): sentences longer than 150 tokens are truncated to a length of 150 tokens, and sentences shorter than 150 tokens are padded with zeros at the end so that they can be concatenated together with other sequences to form contiguous batches.

# %% [markdown]
# The RNN that looks at the tokens in their natural order will spend its last iterations seeing only vectors that encode padding—possibly for several hundreds of iterations if the original sentence was short. The information stored in the internal state of the RNN will gradually fade out as it gets exposed to these meaningless inputs.

# %% [markdown]
# We need some way to tell the RNN that it should skip these iterations. There’s an API for that: `masking`.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>tf.keras.layers.Masking</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Masking</div>

# %% [markdown]
# ### Model Leveraging Embedding Layer With Masking Enabled

# %%
k.clear_session()
inputs = tf.keras.Input(shape=(None,), dtype="int64")
embedded = layers.Embedding(input_dim=max_tokens
                            ,output_dim=256
                            ,mask_zero=True)(inputs)
x = layers.Bidirectional(layers.LSTM(32))(embedded)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="softmax")(x)
model = tf.keras.Model(inputs, outputs)
model.compile(optimizer="rmsprop",
              loss="SparseCategoricalCrossentropy",
              metrics=["accuracy"])
model.summary()

callbacks = [
    tf.keras.callbacks.ModelCheckpoint("LSTM.h5",save_best_only=True)
    ,tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
]
history=model.fit(int_train_ds, validation_data=int_val_ds, epochs=200, callbacks=callbacks)
model = keras.models.load_model("LSTM.h5")
print(f"Test acc: {model.evaluate(int_test_ds)[1]:.3f}")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 256)         256000
#
#  bidirectional (Bidirectiona  (None, 64)               73984
#  l)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 4)                 260
#
# =================================================================
# Total params: 330,244
# Trainable params: 330,244
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 3563/3563 [==============================] - 64s 14ms/step - loss: 0.4907 - accuracy: 0.8250 - val_loss: 0.4180 - val_accuracy: 0.8538
# Epoch 2/200
# 3563/3563 [==============================] - 35s 10ms/step - loss: 0.4157 - accuracy: 0.8533 - val_loss: 0.3962 - val_accuracy: 0.8605
# Epoch 3/200
# 3563/3563 [==============================] - 35s 10ms/step - loss: 0.3978 - accuracy: 0.8583 - val_loss: 0.3851 - val_accuracy: 0.8630
# Epoch 4/200
# 3563/3563 [==============================] - 36s 10ms/step - loss: 0.3842 - accuracy: 0.8647 - val_loss: 0.3814 - val_accuracy: 0.8667
# Epoch 5/200
# 3563/3563 [==============================] - 35s 10ms/step - loss: 0.3741 - accuracy: 0.8680 - val_loss: 0.3812 - val_accuracy: 0.8672
# Epoch 6/200
# 3563/3563 [==============================] - 36s 10ms/step - loss: 0.3641 - accuracy: 0.8714 - val_loss: 0.3789 - val_accuracy: 0.8692
# Epoch 7/200
# 3563/3563 [==============================] - 35s 10ms/step - loss: 0.3562 - accuracy: 0.8744 - val_loss: 0.3747 - val_accuracy: 0.8682
# Epoch 8/200
# 3563/3563 [==============================] - 36s 10ms/step - loss: 0.3484 - accuracy: 0.8773 - val_loss: 0.3759 - val_accuracy: 0.8710
# Epoch 9/200
# 3563/3563 [==============================] - 35s 10ms/step - loss: 0.3411 - accuracy: 0.8798 - val_loss: 0.3801 - val_accuracy: 0.8725
# Epoch 10/200
# 3563/3563 [==============================] - 35s 10ms/step - loss: 0.3328 - accuracy: 0.8831 - val_loss: 0.3811 - val_accuracy: 0.8715
# Epoch 11/200
# 3563/3563 [==============================] - 35s 10ms/step - loss: 0.3258 - accuracy: 0.8866 - val_loss: 0.3845 - val_accuracy: 0.8703
# Epoch 12/200
# 3563/3563 [==============================] - 35s 10ms/step - loss: 0.3157 - accuracy: 0.8895 - val_loss: 0.3938 - val_accuracy: 0.8703
# 238/238 [==============================] - 4s 5ms/step - loss: 0.3878 - accuracy: 0.8633
# Test acc: 0.863

# %% [markdown]
# ### Post Modeling Metrics

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
losses = history.history['loss']
accs = history.history['accuracy']
val_losses = history.history['val_loss']
val_accs = history.history['val_accuracy']
epochs = len(losses)
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#      loss  accuracy  val_loss  val_accuracy
# 7   0.348     0.877     0.376         0.871
# 8   0.341     0.880     0.380         0.873
# 9   0.333     0.883     0.381         0.872
# 10  0.326     0.887     0.385         0.870
# 11  0.316     0.889     0.394         0.870

# %%
plt.subplots(figsize=(16,12))
plt.tight_layout()
display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 211)
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 212)
# Out:
# <ipython-input-5-68a99822f5d5>:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(subplot)

# %%
y_test = np.concatenate([y for x, y in int_test_ds], axis=0)
pred_classes = np.argmax(model.predict(int_test_ds), axis=-1)
# Out:
# 238/238 [==============================] - 3s 4ms/step

# %%
print_validation_report(y_test, pred_classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87      1900
#            1       0.92      0.92      0.92      1900
#            2       0.85      0.81      0.83      1900
#            3       0.81      0.84      0.82      1900
#
#     accuracy                           0.86      7600
#    macro avg       0.86      0.86      0.86      7600
# weighted avg       0.86      0.86      0.86      7600
#
# Accuracy Score: 0.8632894736842105
# Root Mean Square Error: 0.6543377527980807

# %%
plot_confusion_matrix(y_test,pred_classes)
