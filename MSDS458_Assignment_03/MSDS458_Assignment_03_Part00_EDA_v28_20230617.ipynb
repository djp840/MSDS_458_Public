# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/main/images2/NorthwesternHeader.png?raw=1" />

# %% [markdown]
# ## MSDS458 Research Assignment 3

# %% [markdown]
# ### Analyze AG_NEWS_SUBSET Data <br>
#
# AG is a collection of more than 1 million news articles. News articles have been gathered from more than 2000 news sources by ComeToMyHead in more than 1 year of activity. ComeToMyHead is an academic news search engine which has been running since July, 2004. The dataset is provided by the academic comunity for research purposes in data mining (clustering, classification, etc), information retrieval (ranking, search, etc), xml, data compression, data streaming, and any other non-commercial activity.<br>
#
# For more information, please refer to the link http://www.di.unipi.it/~gulli/AG_corpus_of_news_articles.html<br>
#
#
# The AG's news topic classification dataset is constructed by choosing 4 largest classes (**World**, **Sports**, **Business**, and **Sci/Tech**) from the original corpus. Each class contains 30,000 training samples and 1,900 testing samples. The total number of training samples is 120,000 and testing 7,600.<br>
#
# Homepage: https://arxiv.org/abs/1509.01626<br>
#
# Source code: tfds.text.AGNewsSubset
#
# Versions:
#
# 1.0.0 (default): No release notes.
# Download size: 11.24 MiB
#
# Dataset size: 35.79 MiB

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>More Technical</b>: Throughout the notebook. This types of boxes provide more technical details and extra references about what you are seeing. They contain helpful tips, but you can safely skip them the first time you run through the code.
# </div>

# %% [markdown]
# ## Import packages

# %%
import datetime
from packaging import version
from collections import Counter
import numpy as np
import pandas as pd
import time
import os
import re
import string

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import nltk
from nltk.corpus import stopwords

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as k

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ## Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.12.0

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.12.0

# %% [markdown]
# ## Visualization Utility Functions

# %%
def print_validation_report(test_labels, predictions):
    print("Classification Report")
    print(classification_report(test_labels, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(test_labels, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(test_labels, predictions))))

def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend([metric, 'val_'+metric])

# %% [markdown]
# ## Mount Google Drive to Colab Environment

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %% [markdown]
# ### Load AG News Subset Data
# <div class="alert alert-block alert-info">
#     <b> ag_news_subset</b><br>
#     See https://www.tensorflow.org/datasets/catalog/ag_news_subset
#     </div>

# %% [markdown]
# Get all the words in the documents (as well as the number of words in each document) by using the encoder to get the indices associated with each token and then translating the indices to tokens. But first we need to get the "unpadded" new articles so that we can get their length.

# %%
#register  ag_news_subset so that tfds.load doesn't generate a checksum (mismatch) error
# !python -m tensorflow_datasets.scripts.download_and_prepare \
        --register_checksums --datasets=ag_news_subset

# https://www.tensorflow.org/datasets/splits
# The full `train` and `test` splits, interleaved together.
ri = tfds.core.ReadInstruction('train') + tfds.core.ReadInstruction('test')
dataset_all, info = tfds.load('ag_news_subset', with_info=True,  split=ri, as_supervised=True)
text_only_dataset_all=dataset_all.map(lambda x, y: x)
# Out:
# W0618 00:00:36.692711 139883900770112 download_and_prepare.py:46] ***`tfds build` should be used instead of `download_and_prepare`.***
# INFO[build.py]: Loading dataset ag_news_subset from imports: tensorflow_datasets.datasets.ag_news_subset.ag_news_subset_dataset_builder
# 2023-06-18 00:00:37.810542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-18 00:00:39.609962: W tensorflow/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# INFO[dataset_info.py]: Load pre-computed DatasetInfo (eg: splits, num examples,...) from GCS: ag_news_subset/1.0.0
# INFO[dataset_info.py]: Load dataset info from /tmp/tmpt7mhfv_otfds
# INFO[dataset_info.py]: Fields info.[description, splits, supervised_keys, module_name] from disk and from code do not match. Keeping the one from code.
# INFO[build.py]: download_and_prepare for dataset ag_news_subset/1.0.0...
# INFO[dataset_builder.py]: Generating dataset ag_news_subset (/root/tensorflow_datasets/ag_news_subset/1.0.0)
# Downloading and preparing dataset 11.24 MiB (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to /root/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
#
#
#
# INFO[download_manager.py]: Downloading https://drive.google.com/uc?export=download&id=0Bz8a_Dbh9QhbUDNpeUdjb0wxRms into /root/tensorflow_datasets/downloads/ucexport_download_id_0Bz8a_Dbh9QhbUDNpeUdjb0wxj4g1umFAV8OV-uDwxSJR0LdxO_k1jxMuFWwAfNX9jos.tmp.9b28d2e5508c405e8f41b9c8470e9456...
# Dl Completed...: 0 url [00:00, ? url/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:   0% 0/11 [00:15<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:15, ? file/s]
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:   9% 1/11 [00:15<02:30, 15.03s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:  18% 2/11 [00:15<02:15, 15.03s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:  27% 3/11 [00:15<02:00, 15.03s/ MiB]
#
# Extraction completed...: 0 file [00:15, ? file/s]
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:  36% 4/11 [00:15<00:20,  2.94s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:  45% 5/11 [00:15<00:17,  2.94s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:  55% 6/11 [00:15<00:14,  2.94s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:  64% 7/11 [00:15<00:11,  2.94s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:  73% 8/11 [00:15<00:08,  2.94s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:  82% 9/11 [00:15<00:05,  2.94s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...:  91% 10/11 [00:15<00:02,  2.94s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:15<?, ? url/s]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.43s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.43s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.43s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.43s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.43s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Extraction completed...:   0% 0/4 [00:15<?, ? file/s]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.43s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.43s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.43s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.43s/ url]
# Dl Size...: 100% 11/11 [00:15<00:00,  2.94s/ MiB]
#
# Extraction completed...: 100% 4/4 [00:15<00:00,  3.92s/ file]
# Dl Size...: 100% 11/11 [00:15<00:00,  1.42s/ MiB]
# Dl Completed...: 100% 1/1 [00:15<00:00, 15.67s/ url]
# Generating splits...:   0% 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0% 0/120000 [00:00<?, ? examples/s]
# Generating train examples...:   1% 1259/120000 [00:00<00:09, 12589.59 examples/s]
# Generating train examples...:   2% 2518/120000 [00:00<00:09, 12458.52 examples/s]
# Generating train examples...:   3% 3798/120000 [00:00<00:09, 12610.86 examples/s]
# Generating train examples...:   4% 5073/120000 [00:00<00:09, 12662.77 examples/s]
# Generating train examples...:   5% 6340/120000 [00:00<00:09, 12611.05 examples/s]
# Generating train examples...:   6% 7642/120000 [00:00<00:08, 12747.46 examples/s]
# Generating train examples...:   7% 8935/120000 [00:00<00:08, 12806.01 examples/s]
# Generating train examples...:   9% 10216/120000 [00:00<00:08, 12798.73 examples/s]
# Generating train examples...:  10% 11510/120000 [00:00<00:08, 12839.71 examples/s]
# Generating train examples...:  11% 12795/120000 [00:01<00:08, 12766.31 examples/s]
# Generating train examples...:  12% 14072/120000 [00:01<00:08, 12615.72 examples/s]
# Generating train examples...:  13% 15367/120000 [00:01<00:08, 12714.87 examples/s]
# Generating train examples...:  14% 16639/120000 [00:01<00:08, 12540.50 examples/s]
# Generating train examples...:  15% 17894/120000 [00:01<00:08, 12493.27 examples/s]
# Generating train examples...:  16% 19150/120000 [00:01<00:08, 12512.16 examples/s]
# Generating train examples...:  17% 20431/120000 [00:01<00:07, 12599.85 examples/s]
# Generating train examples...:  18% 21704/120000 [00:01<00:07, 12637.25 examples/s]
# Generating train examples...:  19% 22990/120000 [00:01<00:07, 12701.05 examples/s]
# Generating train examples...:  20% 24284/120000 [00:01<00:07, 12770.02 examples/s]
# Generating train examples...:  21% 25573/120000 [00:02<00:07, 12803.45 examples/s]
# Generating train examples...:  22% 26854/120000 [00:02<00:07, 12772.89 examples/s]
# Generating train examples...:  23% 28160/120000 [00:02<00:07, 12857.63 examples/s]
# Generating train examples...:  25% 29446/120000 [00:02<00:07, 12744.69 examples/s]
# Generating train examples...:  26% 30722/120000 [00:02<00:07, 12748.85 examples/s]
# Generating train examples...:  27% 31998/120000 [00:02<00:06, 12658.46 examples/s]
# Generating train examples...:  28% 33273/120000 [00:02<00:06, 12684.58 examples/s]
# Generating train examples...:  29% 34560/120000 [00:02<00:06, 12737.10 examples/s]
# Generating train examples...:  30% 35834/120000 [00:02<00:06, 12641.59 examples/s]
# Generating train examples...:  31% 37138/120000 [00:02<00:06, 12757.85 examples/s]
# Generating train examples...:  32% 38415/120000 [00:03<00:06, 12645.85 examples/s]
# Generating train examples...:  33% 39703/120000 [00:03<00:06, 12714.84 examples/s]
# Generating train examples...:  34% 40975/120000 [00:03<00:06, 12704.45 examples/s]
# Generating train examples...:  35% 42263/120000 [00:03<00:06, 12753.00 examples/s]
# Generating train examples...:  36% 43539/120000 [00:03<00:06, 12554.51 examples/s]
# Generating train examples...:  37% 44826/120000 [00:03<00:05, 12646.37 examples/s]
# Generating train examples...:  38% 46107/120000 [00:03<00:05, 12692.60 examples/s]
# Generating train examples...:  39% 47377/120000 [00:03<00:05, 12654.97 examples/s]
# Generating train examples...:  41% 48649/120000 [00:03<00:05, 12671.40 examples/s]
# Generating train examples...:  42% 49954/120000 [00:03<00:05, 12781.59 examples/s]
# Generating train examples...:  43% 51233/120000 [00:04<00:05, 12731.70 examples/s]
# Generating train examples...:  44% 52528/120000 [00:04<00:05, 12794.33 examples/s]
# Generating train examples...:  45% 53808/120000 [00:04<00:05, 12748.25 examples/s]
# Generating train examples...:  46% 55105/120000 [00:04<00:05, 12813.07 examples/s]
# Generating train examples...:  47% 56387/120000 [00:04<00:04, 12758.20 examples/s]
# Generating train examples...:  48% 57663/120000 [00:04<00:04, 12692.50 examples/s]
# Generating train examples...:  49% 58933/120000 [00:04<00:04, 12659.56 examples/s]
# Generating train examples...:  50% 60200/120000 [00:04<00:04, 12643.06 examples/s]
# Generating train examples...:  51% 61465/120000 [00:04<00:04, 12445.36 examples/s]
# Generating train examples...:  52% 62735/120000 [00:04<00:04, 12517.00 examples/s]
# Generating train examples...:  53% 64008/120000 [00:05<00:04, 12578.11 examples/s]
# Generating train examples...:  54% 65279/120000 [00:05<00:04, 12617.11 examples/s]
# Generating train examples...:  55% 66562/120000 [00:05<00:04, 12678.88 examples/s]
# Generating train examples...:  57% 67864/120000 [00:05<00:04, 12779.28 examples/s]
# Generating train examples...:  58% 69175/120000 [00:05<00:03, 12876.65 examples/s]
# Generating train examples...:  59% 70463/120000 [00:05<00:03, 12837.21 examples/s]
# Generating train examples...:  60% 71772/120000 [00:05<00:03, 12912.22 examples/s]
# Generating train examples...:  61% 73066/120000 [00:05<00:03, 12920.37 examples/s]
# Generating train examples...:  62% 74359/120000 [00:05<00:03, 12857.71 examples/s]
# Generating train examples...:  63% 75645/120000 [00:05<00:03, 12846.48 examples/s]
# Generating train examples...:  64% 76946/120000 [00:06<00:03, 12892.51 examples/s]
# Generating train examples...:  65% 78236/120000 [00:06<00:03, 12771.56 examples/s]
# Generating train examples...:  66% 79537/120000 [00:06<00:03, 12841.37 examples/s]
# Generating train examples...:  67% 80823/120000 [00:06<00:03, 12846.12 examples/s]
# Generating train examples...:  68% 82109/120000 [00:06<00:02, 12847.90 examples/s]
# Generating train examples...:  70% 83407/120000 [00:06<00:02, 12884.70 examples/s]
# Generating train examples...:  71% 84696/120000 [00:06<00:02, 12390.76 examples/s]
# Generating train examples...:  72% 85940/120000 [00:06<00:02, 11937.92 examples/s]
# Generating train examples...:  73% 87149/120000 [00:06<00:02, 11979.08 examples/s]
# Generating train examples...:  74% 88391/120000 [00:06<00:02, 12106.43 examples/s]
# Generating train examples...:  75% 89683/120000 [00:07<00:02, 12342.46 examples/s]
# Generating train examples...:  76% 90960/120000 [00:07<00:02, 12467.17 examples/s]
# Generating train examples...:  77% 92261/120000 [00:07<00:02, 12625.88 examples/s]
# Generating train examples...:  78% 93526/120000 [00:07<00:02, 12626.20 examples/s]
# Generating train examples...:  79% 94809/120000 [00:07<00:01, 12684.64 examples/s]
# Generating train examples...:  80% 96100/120000 [00:07<00:01, 12750.30 examples/s]
# Generating train examples...:  81% 97376/120000 [00:07<00:01, 12716.74 examples/s]
# Generating train examples...:  82% 98660/120000 [00:07<00:01, 12752.46 examples/s]
# Generating train examples...:  83% 99945/120000 [00:07<00:01, 12780.88 examples/s]
# Generating train examples...:  84% 101224/120000 [00:07<00:01, 12641.61 examples/s]
# Generating train examples...:  85% 102507/120000 [00:08<00:01, 12694.50 examples/s]
# Generating train examples...:  86% 103790/120000 [00:08<00:01, 12731.95 examples/s]
# Generating train examples...:  88% 105064/120000 [00:08<00:01, 12709.86 examples/s]
# Generating train examples...:  89% 106336/120000 [00:08<00:01, 12260.36 examples/s]
# Generating train examples...:  90% 107600/120000 [00:08<00:01, 12368.36 examples/s]
# Generating train examples...:  91% 108854/120000 [00:08<00:00, 12414.74 examples/s]
# Generating train examples...:  92% 110108/120000 [00:08<00:00, 12450.41 examples/s]
# Generating train examples...:  93% 111395/120000 [00:08<00:00, 12573.62 examples/s]
# Generating train examples...:  94% 112682/120000 [00:08<00:00, 12658.83 examples/s]
# Generating train examples...:  95% 113949/120000 [00:09<00:00, 12583.16 examples/s]
# Generating train examples...:  96% 115240/120000 [00:09<00:00, 12680.23 examples/s]
# Generating train examples...:  97% 116509/120000 [00:09<00:00, 12676.98 examples/s]
# Generating train examples...:  98% 117788/120000 [00:09<00:00, 12709.49 examples/s]
# Generating train examples...:  99% 119060/120000 [00:09<00:00, 12658.09 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete9XWCVE/ag_news_subset-train.tfrecord*...:   0% 0/120000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete9XWCVE/ag_news_subset-train.tfrecord*...:   2% 1911/120000 [00:00<00:06, 19108.29 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete9XWCVE/ag_news_subset-train.tfrecord*...:  40% 48200/120000 [00:00<00:00, 280131.16 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete9XWCVE/ag_news_subset-train.tfrecord*...:  81% 96925/120000 [00:00<00:00, 374693.64 examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete9XWCVE/ag_news_subset-train.tfrecord*. Number of examples: 120000 (shards: [120000])
# Generating splits...:  50% 1/2 [00:09<00:09,  9.84s/ splits]
# Generating test examples...:   0% 0/7600 [00:00<?, ? examples/s]
# Generating test examples...:  16% 1242/7600 [00:00<00:00, 12417.88 examples/s]
# Generating test examples...:  33% 2512/7600 [00:00<00:00, 12580.71 examples/s]
# Generating test examples...:  50% 3771/7600 [00:00<00:00, 12421.89 examples/s]
# Generating test examples...:  66% 5014/7600 [00:00<00:00, 12288.32 examples/s]
# Generating test examples...:  82% 6244/7600 [00:00<00:00, 12130.08 examples/s]
# Generating test examples...:  99% 7539/7600 [00:00<00:00, 12402.02 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete9XWCVE/ag_news_subset-test.tfrecord*...:   0% 0/7600 [00:00<?, ? examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incomplete9XWCVE/ag_news_subset-test.tfrecord*. Number of examples: 7600 (shards: [7600])
# Dataset ag_news_subset downloaded and prepared to /root/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.
# INFO[build.py]: Dataset generation complete...
#
# tfds.core.DatasetInfo(
#     name='ag_news_subset',
#     full_name='ag_news_subset/1.0.0',
#     description="""
#     AG is a collection of more than 1 million news articles. News articles have been
#     gathered from more than 2000 news sources by ComeToMyHead in more than 1 year of
#     activity. ComeToMyHead is an academic news search engine which has been running
#     since July, 2004. The dataset is provided by the academic comunity for research
#     purposes in data mining (clustering, classification, etc), information retrieval
#     (ranking, search, etc), xml, data compression, data streaming, and any other
#     non-commercial activity. For more information, please refer to the link
#     http://www.di.unipi.it/~gulli/AG_corpus_of_news_articles.html .
#
#     The AG's news topic classification dataset is constructed by Xiang Zhang
#     (xiang.zhang@nyu.edu) from the dataset above. It is used as a text
#     classification benchmark in the following paper: Xiang Zhang, Junbo Zhao, Yann
#     LeCun. Character-level Convolutional Networks for Text Classification. Advances
#     in Neural Information Processing Systems 28 (NIPS 2015).
#
#     The AG's news topic classification dataset is constructed by choosing 4 largest
#     classes from the original corpus. Each class contains 30,000 training samples
#     and 1,900 testing samples. The total number of training samples is 120,000 and
#     testing 7,600.
#     """,
#     homepage='https://arxiv.org/abs/1509.01626',
#     data_path=PosixGPath('/tmp/tmpt7mhfv_otfds'),
#     file_format=tfrecord,
#     download_size=11.24 MiB,
#     dataset_size=35.79 MiB,
#     features=FeaturesDict({
#         'description': Text(shape=(), dtype=string),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=4),
#         'title': Text(shape=(), dtype=string),
#     }),
#     supervised_keys=('description', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=7600, num_shards=1>,
#         'train': <SplitInfo num_examples=120000, num_shards=1>,
#     },
#     citation="""@misc{zhang2015characterlevel,
#         title={Character-level Convolutional Networks for Text Classification},
#         author={Xiang Zhang and Junbo Zhao and Yann LeCun},
#         year={2015},
#         eprint={1509.01626},
#         archivePrefix={arXiv},
#         primaryClass={cs.LG}
#     }""",
# )

# %% [markdown]
# ###  EDA AG News Subset

# %% [markdown]
# **Get information about the ag_news_subset dataset. We combined the training and test data for a total of 127,600 news articles.**

# %%
tfds.as_dataframe(dataset_all.take(10),info)
# Out:
#                                          description  label
# 0  b'AMD #39;s new dual-core Opteron chip is desi...      3
# 1  b'Reuters - Major League Baseball\\Monday anno...      1
# 2  b'President Bush #39;s  quot;revenue-neutral q...      2
# 3  b'Britain will run out of leading scientists u...      3
# 4  b'London, England (Sports Network) - England m...      1
# 5  b'TOKYO - Sony Corp. is banking on the \\$3 bi...      0
# 6  b'Giant pandas may well prefer bamboo to lapto...      3
# 7  b'VILNIUS, Lithuania - Lithuania #39;s main pa...      0
# 8  b'Witnesses in the trial of a US soldier charg...      0
# 9  b'Dan Olsen of Ponte Vedra Beach, Fla., shot a...      1

# %% [markdown]
# ### Review Labels (Categories)

# %%
categories =dict(enumerate(info.features["label"].names))
print(f'Dictionary: ',categories)
# Out:
# Dictionary:  {0: 'World', 1: 'Sports', 2: 'Business', 3: 'Sci/Tech'}

# %% [markdown]
# ### Review Class Balance
# The 127,600 news articles are evenly distributed among the 4 categories

# %%
train_categories = [categories[label] for label in dataset_all.map(lambda text, label: label).as_numpy_iterator()]
Counter(train_categories).most_common()
# Out:
# [('Sci/Tech', 31900), ('Sports', 31900), ('Business', 31900), ('World', 31900)]

# %% [markdown]
# ### Preprocess Dataset for EDA

# %%
def custom_stopwords(input_text):
    lowercase = tf.strings.lower(input_text)
    stripped_punct = tf.strings.regex_replace(lowercase
                                  ,'[%s]' % re.escape(string.punctuation)
                                  ,'')
    return tf.strings.regex_replace(stripped_punct, r'\b(' + r'|'.join(STOPWORDS) + r')\b\s*',"")

# %%
nltk.download('stopwords',quiet=True)
STOPWORDS = stopwords.words("english")

# %% [markdown]
# ### TextVectorization and Adapt() Vocabulary

# %%
# %%time
max_tokens = None
text_vectorization=layers.TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    standardize=custom_stopwords
)
text_vectorization.adapt(text_only_dataset_all)
# Out:
# CPU times: user 5min 12s, sys: 44.7 s, total: 5min 57s
# Wall time: 3min 18s

# %%
# %%time
doc_sizes = []
corpus = []
for example, _ in dataset_all.as_numpy_iterator():
  enc_example = text_vectorization(example)
  doc_sizes.append(len(enc_example))
  corpus+=list(enc_example.numpy())
# Out:
# CPU times: user 16min 33s, sys: 60 s, total: 17min 33s
# Wall time: 16min 3s

# %%
print(f"There are {len(corpus)} words in the corpus of {len(doc_sizes)} news articles.")
print(f"Each news article has between {min(doc_sizes)} and {max(doc_sizes)} tokens in it.")
# Out:
# There are 2579419 words in the corpus of 127600 news articles.
# Each news article has between 2 and 95 tokens in it.

# %%
print(f"There are {len(text_vectorization.get_vocabulary())} vocabulary words in the corpus.")
# Out:
# There are 95827 vocabulary words in the corpus.

# %%
vocab = np.array(text_vectorization.get_vocabulary())
print(vocab[:50])
# Out:
# ['' '[UNK]' '39s' 'said' 'new' 'us' 'reuters' 'ap' 'two' 'first' 'monday'
#  'wednesday' 'tuesday' 'thursday' 'company' 'friday' 'inc' 'one' 'world'
#  'yesterday' 'last' 'york' 'year' 'president' 'million' 'oil' 'corp'
#  'united' 'would' 'sunday' 'years' 'week' 'people' 'today' 'three'
#  'government' 'could' 'quot' 'group' 'time' 'percent' 'game' 'saturday'
#  'software' 'night' 'next' 'prices' 'iraq' 'security' 'announced']

# %%
plt.figure(figsize=(15,9))
plt.hist(doc_sizes, bins=20,range = (0,80))
plt.xlabel("Tokens Per Document")
plt.ylabel("Number of AG News Articles");
